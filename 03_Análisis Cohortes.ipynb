# %% [markdown]
# # Análisis de Cohortes
#
# **Entendiendo el comportamiento  lo largo de los meses**
#
# Es útil para entender cómo evoluciona el valor de los clientes a lo largo del tiempo y evaluar la efectividad de las acciones sobre segmentos específicos.
#
# Esta técnica grupa a los clientes en función de un atributo común (generalmente el momento en que realizaron una acción, como su primera compra o registro) para analizar su comportamiento a lo largo del tiempo. El objetivo es identificar patrones de retención, engagement o deserción dentro de estos grupos, llamados cohortes.

# %% [markdown]
# ## Importación de librerías y carga de datos

# %%
# Importación de librerías
import pandas as pd

productos = pd.read_csv('00_Datasets/productos_final.csv', parse_dates=['Fecha'])

# %%
productos.head()
# Out:
#    ID_Cliente      Fecha  ID_Transaccion Categoria_Producto Producto  \
# 0           1 2023-01-21            3442                0H2    6OUVC
# 1           1 2023-01-21            3442                N8U    CEBU8
# 2           2 2023-03-24           14177                TVL    2SLS0
# 3           2 2023-06-19           30451                F9B    GZ6VU
# 4           3 2023-01-01              90                LPF    Y1M2E
#
#    Coste_Unitario  Cantidad  Precio_Unitario  Total_Venta
# 0            7.64       4.0            10.50        42.00
# 1            4.57       4.0             5.79        23.16
# 2            4.60       3.0             7.77        23.31
# 3            9.04       3.0            15.00        45.00
# 4            3.37       4.0             4.08        16.32

# %% [markdown]
# ## Asignar el mes de cada transacción
#
# Creamos una nueva columna que contiene solo el mes y el año de cada transacción.

# %%
# Crear la columna 'MesTransaccion' a partir de 'Fecha' en formato Period (mes y año)
productos['MesTransaccion'] = productos['Fecha'].dt.to_period('M')

# Revisamos las primeras filas para confirmar
productos[['ID_Cliente', 'Fecha', 'MesTransaccion']].head()
# Out:
#    ID_Cliente      Fecha MesTransaccion
# 0           1 2023-01-21        2023-01
# 1           1 2023-01-21        2023-01
# 2           2 2023-03-24        2023-03
# 3           2 2023-06-19        2023-06
# 4           3 2023-01-01        2023-01

# %%
# Revisamos que mantenemos el mismo número de clientes
productos.ID_Cliente.nunique()
# Out:
# 20688

# %%
# Sacamos una vista ordenada de los datos por Cliente y MesTransaccion
productos.sort_values(by=['ID_Cliente','MesTransaccion']).head(20)
# Out:
#     ID_Cliente      Fecha  ID_Transaccion Categoria_Producto Producto  \
# 0            1 2023-01-21            3442                0H2    6OUVC
# 1            1 2023-01-21            3442                N8U    CEBU8
# 2            2 2023-03-24           14177                TVL    2SLS0
# 3            2 2023-06-19           30451                F9B    GZ6VU
# 4            3 2023-01-01              90                LPF    Y1M2E
# 5            3 2023-01-01              90                TW8    WHV3G
# 6            3 2023-01-01              90                TW8    WALAE
# 7            4 2023-07-11           34042                69B    APEJQ
# 8            4 2023-11-09           54618                YMJ    QR49F
# 9            4 2023-11-09           54618                29A    RBNO8
# 10           4 2023-11-09           54618                N8U    89ULV
# 11           4 2023-11-09           54618                JR5    KWDJZ
# 12           5 2023-02-08            6370                P42    DMJ70
# 13           5 2023-02-21            8624                P42    DMJ70
# 14           5 2023-03-23           14133                P42    DMJ70
# 15           5 2023-05-28           26651                P42    DMJ70
# 16           5 2023-07-05           33043                LGI    EIFZN
# 17           6 2023-03-31           15292                1EO    2FGPG
# 18           6 2023-03-31           15292                1VL    2K09R
# 19           6 2023-03-31           15292                Z23    Q9TU6
#
#     Coste_Unitario  Cantidad  Precio_Unitario  Total_Venta MesTransaccion
# 0             7.64       4.0            10.50        42.00        2023-01
# 1             4.57       4.0             5.79        23.16        2023-01
# 2             4.60       3.0             7.77        23.31        2023-03
# 3             9.04       3.0            15.00        45.00        2023-06
# 4             3.37       4.0             4.08        16.32        2023-01
# 5             1.15       3.0             1.38         4.14        2023-01
# 6             0.89       3.0             1.38         4.14        2023-01
# 7             3.48       5.0             6.69        33.45        2023-07
# 8             5.31       4.0             7.37        29.48        2023-11
# 9             5.67       4.0             8.65        34.60        2023-11
# 10            3.41       4.0             5.12        20.48        2023-11
# 11            2.73       4.0             5.46        21.84        2023-11
# 12            3.23       6.0             5.03        30.18        2023-02
# 13            4.13       7.0             5.03        35.21        2023-02
# 14            5.01       5.0             5.72        28.60        2023-03
# 15            5.31       4.0             7.16        28.64        2023-05
# 16            5.71       3.0             7.06        21.18        2023-07
# 17            5.64       3.0            10.54        31.62        2023-03
# 18            8.15       4.0            10.89        43.56        2023-03
# 19            2.24       4.0             4.12        16.48        2023-03

# %% [markdown]
# **Explicación rápida del método trasform() y su diferencia con respecto al método agg()**
#
# - **agg**: Permite realizar agregaciones a nivel de grupo, como sumas, promedios, o en el caso anterior, calcular la Recency usando la última fecha de cada cliente. agg devuelve un DataFrame más pequeño porque resume los datos de cada grupo.
#
# - **transform**: Aplica una función a cada grupo, pero devuelve un resultado con la misma forma que el DataFrame original. Es útil cuando queremos aplicar una transformación y mantener el mismo número de filas que en el original.

# %%
productos.groupby('ID_Cliente')['MesTransaccion'].agg('min')
# Out:
# ID_Cliente
# 1        2023-01
# 2        2023-03
# 3        2023-01
# 4        2023-07
# 5        2023-02
#           ...
# 22621    2023-12
# 22622    2023-12
# 22623    2023-12
# 22624    2023-12
# 22625    2023-12
# Name: MesTransaccion, Length: 20688, dtype: period[M]

# %%
productos.groupby('ID_Cliente')['MesTransaccion'].transform('min')
# Out:
# 0        2023-01
# 1        2023-01
# 2        2023-03
# 3        2023-03
# 4        2023-01
#           ...
# 78261    2023-11
# 78262    2023-10
# 78263    2023-06
# 78264    2023-10
# 78265    2023-08
# Name: MesTransaccion, Length: 78266, dtype: period[M]

# %% [markdown]
# ## Añadir el MesCohorte
#
# El mes en el que hace la primera compra

# %%
# Calculo la nueva variable
productos['MesCohorte'] = productos.groupby('ID_Cliente')['MesTransaccion'].transform('min')

# %%
# Sacamos una vista ordenada de los datos por Cliente y MesTransaccion
productos.sort_values(by=['ID_Cliente','MesTransaccion']).head(20)
# Out:
#     ID_Cliente      Fecha  ID_Transaccion Categoria_Producto Producto  \
# 0            1 2023-01-21            3442                0H2    6OUVC
# 1            1 2023-01-21            3442                N8U    CEBU8
# 2            2 2023-03-24           14177                TVL    2SLS0
# 3            2 2023-06-19           30451                F9B    GZ6VU
# 4            3 2023-01-01              90                LPF    Y1M2E
# 5            3 2023-01-01              90                TW8    WHV3G
# 6            3 2023-01-01              90                TW8    WALAE
# 7            4 2023-07-11           34042                69B    APEJQ
# 8            4 2023-11-09           54618                YMJ    QR49F
# 9            4 2023-11-09           54618                29A    RBNO8
# 10           4 2023-11-09           54618                N8U    89ULV
# 11           4 2023-11-09           54618                JR5    KWDJZ
# 12           5 2023-02-08            6370                P42    DMJ70
# 13           5 2023-02-21            8624                P42    DMJ70
# 14           5 2023-03-23           14133                P42    DMJ70
# 15           5 2023-05-28           26651                P42    DMJ70
# 16           5 2023-07-05           33043                LGI    EIFZN
# 17           6 2023-03-31           15292                1EO    2FGPG
# 18           6 2023-03-31           15292                1VL    2K09R
# 19           6 2023-03-31           15292                Z23    Q9TU6
#
#     Coste_Unitario  Cantidad  Precio_Unitario  Total_Venta MesTransaccion  \
# 0             7.64       4.0            10.50        42.00        2023-01
# 1             4.57       4.0             5.79        23.16        2023-01
# 2             4.60       3.0             7.77        23.31        2023-03
# 3             9.04       3.0            15.00        45.00        2023-06
# 4             3.37       4.0             4.08        16.32        2023-01
# 5             1.15       3.0             1.38         4.14        2023-01
# 6             0.89       3.0             1.38         4.14        2023-01
# 7             3.48       5.0             6.69        33.45        2023-07
# 8             5.31       4.0             7.37        29.48        2023-11
# 9             5.67       4.0             8.65        34.60        2023-11
# 10            3.41       4.0             5.12        20.48        2023-11
# 11            2.73       4.0             5.46        21.84        2023-11
# 12            3.23       6.0             5.03        30.18        2023-02
# 13            4.13       7.0             5.03        35.21        2023-02
# 14            5.01       5.0             5.72        28.60        2023-03
# 15            5.31       4.0             7.16        28.64        2023-05
# 16            5.71       3.0             7.06        21.18        2023-07
# 17            5.64       3.0            10.54        31.62        2023-03
# 18            8.15       4.0            10.89        43.56        2023-03
# 19            2.24       4.0             4.12        16.48        2023-03
#
#    MesCohorte
# 0     2023-01
# 1     2023-01
# 2     2023-03
# 3     2023-03
# 4     2023-01
# 5     2023-01
# 6     2023-01
# 7     2023-07
# 8     2023-07
# 9     2023-07
# 10    2023-07
# 11    2023-07
# 12    2023-02
# 13    2023-02
# 14    2023-02
# 15    2023-02
# 16    2023-02
# 17    2023-03
# 18    2023-03
# 19    2023-03

# %% [markdown]
# ## Eiminar los registros de cohortes que no están completas
#
# Al trabajar con las ventanas de 6 meses no nos valen desde la de agosto en adelante

# %%
# Creamos una tabla nueva a la que le asigmanos los datos filtrados
resultados = productos[productos['MesCohorte'] <= '2023-07']
resultados
# Out:
#        ID_Cliente      Fecha  ID_Transaccion Categoria_Producto Producto  \
# 0               1 2023-01-21            3442                0H2    6OUVC
# 1               1 2023-01-21            3442                N8U    CEBU8
# 2               2 2023-03-24           14177                TVL    2SLS0
# 3               2 2023-06-19           30451                F9B    GZ6VU
# 4               3 2023-01-01              90                LPF    Y1M2E
# ...           ...        ...             ...                ...      ...
# 78255        2494 2023-07-27           36500                FU5    3ZY0H
# 78257        3527 2023-04-28           20425                FEW    WG7HI
# 78258        5063 2023-03-13           11915                29A    PO1N6
# 78259       17354 2023-06-29           32041                01F    RVG1H
# 78263       12790 2023-06-04           27905                FEW    7SW5C
#
#        Coste_Unitario  Cantidad  Precio_Unitario  Total_Venta MesTransaccion  \
# 0                7.64       4.0            10.50        42.00        2023-01
# 1                4.57       4.0             5.79        23.16        2023-01
# 2                4.60       3.0             7.77        23.31        2023-03
# 3                9.04       3.0            15.00        45.00        2023-06
# 4                3.37       4.0             4.08        16.32        2023-01
# ...               ...       ...              ...          ...            ...
# 78255            3.34       3.0             4.96        14.88        2023-07
# 78257            4.11       3.0             5.18        15.54        2023-04
# 78258            3.00      10.0             4.96        49.60        2023-03
# 78259            1.47       3.0             1.68         5.04        2023-06
# 78263            7.95       1.0            11.00        11.00        2023-06
#
#       MesCohorte
# 0        2023-01
# 1        2023-01
# 2        2023-03
# 3        2023-03
# 4        2023-01
# ...          ...
# 78255    2023-07
# 78257    2023-04
# 78258    2023-03
# 78259    2023-06
# 78263    2023-06
#
# [61497 rows x 11 columns]

# %%
resultados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61497 entries, 0 to 78263
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID_Cliente          61497 non-null  int64
#  1   Fecha               61497 non-null  datetime64[ns]
#  2   ID_Transaccion      61497 non-null  int64
#  3   Categoria_Producto  61497 non-null  object
#  4   Producto            61497 non-null  object
#  5   Coste_Unitario      61497 non-null  float64
#  6   Cantidad            61497 non-null  float64
#  7   Precio_Unitario     61497 non-null  float64
#  8   Total_Venta         61497 non-null  float64
#  9   MesTransaccion      61497 non-null  period[M]
#  10  MesCohorte          61497 non-null  period[M]
# dtypes: datetime64[ns](1), float64(4), int64(2), object(2), period[M](2)
# memory usage: 5.6+ MB

# %% [markdown]
# ## Transformar las variaibles Mes_ a datetime
#
# Esto permite trabajar mejor con los desplazamientos

# %%
# El proceso clásico da fallos porque ya venimos de un formato period, hay que hacer una transformacion previa
# pd.to_datetime(resultados['MesTransaccion'], format='%Y-%m')

# %%
# Hacemos una copia de la tabla para no machacar la original y hacemos la transformación
resultados = resultados.copy()
resultados['MesTransaccion'] = pd.to_datetime(resultados['MesTransaccion'].astype(str), format='%Y-%m')
resultados['MesCohorte'] = pd.to_datetime(resultados['MesCohorte'].astype(str), format='%Y-%m')

# %%
resultados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61497 entries, 0 to 78263
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID_Cliente          61497 non-null  int64
#  1   Fecha               61497 non-null  datetime64[ns]
#  2   ID_Transaccion      61497 non-null  int64
#  3   Categoria_Producto  61497 non-null  object
#  4   Producto            61497 non-null  object
#  5   Coste_Unitario      61497 non-null  float64
#  6   Cantidad            61497 non-null  float64
#  7   Precio_Unitario     61497 non-null  float64
#  8   Total_Venta         61497 non-null  float64
#  9   MesTransaccion      61497 non-null  datetime64[ns]
#  10  MesCohorte          61497 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), float64(4), int64(2), object(2)
# memory usage: 5.6+ MB

# %% [markdown]
# ## Eliminar los registros que no entran en el análisis
#
# Teniendo presente que la cohorte dura 6 meses, eliminamos aquellos cuyo MesTransaccion sea superior al MesCohorte 5

# %% [markdown]
# **Entendiendo el funcionamiento del desplazamiento de fechas**
#
# Supongamos que tienes una fila con los siguientes valores:
#
# MesCohorte: 2023-01-01
# MesTransaccion: 2023-05-01
#
# - Paso 1: Sumar 5 meses a MesCohorte
# Si MesCohorte es 2023-01-01, entonces al sumar 5 meses (pd.DateOffset(months=5)), obtendrás 2023-06-01.
#
# - Paso 2: Comparar MesTransaccion con la nueva fecha
# Ahora comparas si la fecha de MesTransaccion (2023-05-01) es menor o igual a 2023-06-01. En este caso, sí lo es, porque 2023-05-01 está antes de 2023-06-01.
#
# Resultado:
# Esta fila pasará el filtro y será incluida en el DataFrame final porque la transacción se realizó antes de los 5 meses después del mes de cohorte.
#
# Si MesTransaccion fuera otra fecha:
#
# Por ejemplo, 2023-07-01, entonces no pasaría el filtro, porque esa fecha es posterior a 2023-06-01 (el límite de 5 meses después de MesCohorte).

# %%
resultados[resultados['MesTransaccion'] <= resultados['MesCohorte'] + pd.DateOffset(months=5)]
# Out:
#        ID_Cliente      Fecha  ID_Transaccion Categoria_Producto Producto  \
# 0               1 2023-01-21            3442                0H2    6OUVC
# 1               1 2023-01-21            3442                N8U    CEBU8
# 2               2 2023-03-24           14177                TVL    2SLS0
# 3               2 2023-06-19           30451                F9B    GZ6VU
# 4               3 2023-01-01              90                LPF    Y1M2E
# ...           ...        ...             ...                ...      ...
# 78255        2494 2023-07-27           36500                FU5    3ZY0H
# 78257        3527 2023-04-28           20425                FEW    WG7HI
# 78258        5063 2023-03-13           11915                29A    PO1N6
# 78259       17354 2023-06-29           32041                01F    RVG1H
# 78263       12790 2023-06-04           27905                FEW    7SW5C
#
#        Coste_Unitario  Cantidad  Precio_Unitario  Total_Venta MesTransaccion  \
# 0                7.64       4.0            10.50        42.00     2023-01-01
# 1                4.57       4.0             5.79        23.16     2023-01-01
# 2                4.60       3.0             7.77        23.31     2023-03-01
# 3                9.04       3.0            15.00        45.00     2023-06-01
# 4                3.37       4.0             4.08        16.32     2023-01-01
# ...               ...       ...              ...          ...            ...
# 78255            3.34       3.0             4.96        14.88     2023-07-01
# 78257            4.11       3.0             5.18        15.54     2023-04-01
# 78258            3.00      10.0             4.96        49.60     2023-03-01
# 78259            1.47       3.0             1.68         5.04     2023-06-01
# 78263            7.95       1.0            11.00        11.00     2023-06-01
#
#       MesCohorte
# 0     2023-01-01
# 1     2023-01-01
# 2     2023-03-01
# 3     2023-03-01
# 4     2023-01-01
# ...          ...
# 78255 2023-07-01
# 78257 2023-04-01
# 78258 2023-03-01
# 78259 2023-06-01
# 78263 2023-06-01
#
# [54405 rows x 11 columns]

# %%
# Creamos nueva tabla con resultados filtrados
resultados_filtrados = resultados[resultados['MesTransaccion'] <= resultados['MesCohorte'] + pd.DateOffset(months=5)]
resultados_filtrados
# Out:
#        ID_Cliente      Fecha  ID_Transaccion Categoria_Producto Producto  \
# 0               1 2023-01-21            3442                0H2    6OUVC
# 1               1 2023-01-21            3442                N8U    CEBU8
# 2               2 2023-03-24           14177                TVL    2SLS0
# 3               2 2023-06-19           30451                F9B    GZ6VU
# 4               3 2023-01-01              90                LPF    Y1M2E
# ...           ...        ...             ...                ...      ...
# 78255        2494 2023-07-27           36500                FU5    3ZY0H
# 78257        3527 2023-04-28           20425                FEW    WG7HI
# 78258        5063 2023-03-13           11915                29A    PO1N6
# 78259       17354 2023-06-29           32041                01F    RVG1H
# 78263       12790 2023-06-04           27905                FEW    7SW5C
#
#        Coste_Unitario  Cantidad  Precio_Unitario  Total_Venta MesTransaccion  \
# 0                7.64       4.0            10.50        42.00     2023-01-01
# 1                4.57       4.0             5.79        23.16     2023-01-01
# 2                4.60       3.0             7.77        23.31     2023-03-01
# 3                9.04       3.0            15.00        45.00     2023-06-01
# 4                3.37       4.0             4.08        16.32     2023-01-01
# ...               ...       ...              ...          ...            ...
# 78255            3.34       3.0             4.96        14.88     2023-07-01
# 78257            4.11       3.0             5.18        15.54     2023-04-01
# 78258            3.00      10.0             4.96        49.60     2023-03-01
# 78259            1.47       3.0             1.68         5.04     2023-06-01
# 78263            7.95       1.0            11.00        11.00     2023-06-01
#
#       MesCohorte
# 0     2023-01-01
# 1     2023-01-01
# 2     2023-03-01
# 3     2023-03-01
# 4     2023-01-01
# ...          ...
# 78255 2023-07-01
# 78257 2023-04-01
# 78258 2023-03-01
# 78259 2023-06-01
# 78263 2023-06-01
#
# [54405 rows x 11 columns]

# %%
resultados_filtrados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 54405 entries, 0 to 78263
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID_Cliente          54405 non-null  int64
#  1   Fecha               54405 non-null  datetime64[ns]
#  2   ID_Transaccion      54405 non-null  int64
#  3   Categoria_Producto  54405 non-null  object
#  4   Producto            54405 non-null  object
#  5   Coste_Unitario      54405 non-null  float64
#  6   Cantidad            54405 non-null  float64
#  7   Precio_Unitario     54405 non-null  float64
#  8   Total_Venta         54405 non-null  float64
#  9   MesTransaccion      54405 non-null  datetime64[ns]
#  10  MesCohorte          54405 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), float64(4), int64(2), object(2)
# memory usage: 5.0+ MB

# %% [markdown]
# ## Crear una variable del mes desde el punto de vista del ciclo del cliente

# %%
resultados_filtrados = resultados_filtrados.copy()

# Paso 1: Crear nuevas columnas temporales como Period[M] sin sobrescribir las originales
mes_transaccion_period = resultados_filtrados['MesTransaccion'].dt.to_period('M')
mes_cohorte_period = resultados_filtrados['MesCohorte'].dt.to_period('M')

# Paso 2: Calcular la diferencia en meses entre las columnas temporales
diferencia_meses = mes_transaccion_period - mes_cohorte_period

# Paso 3: Crear la nueva columna 'MesCliente' con la diferencia calculada
resultados_filtrados.loc[:, 'MesCliente'] = 'M' + diferencia_meses.apply(lambda x: str(x.n + 1))

# Mostrar el DataFrame con la nueva columna
resultados_filtrados
# Out:
#        ID_Cliente      Fecha  ID_Transaccion Categoria_Producto Producto  \
# 0               1 2023-01-21            3442                0H2    6OUVC
# 1               1 2023-01-21            3442                N8U    CEBU8
# 2               2 2023-03-24           14177                TVL    2SLS0
# 3               2 2023-06-19           30451                F9B    GZ6VU
# 4               3 2023-01-01              90                LPF    Y1M2E
# ...           ...        ...             ...                ...      ...
# 78255        2494 2023-07-27           36500                FU5    3ZY0H
# 78257        3527 2023-04-28           20425                FEW    WG7HI
# 78258        5063 2023-03-13           11915                29A    PO1N6
# 78259       17354 2023-06-29           32041                01F    RVG1H
# 78263       12790 2023-06-04           27905                FEW    7SW5C
#
#        Coste_Unitario  Cantidad  Precio_Unitario  Total_Venta MesTransaccion  \
# 0                7.64       4.0            10.50        42.00     2023-01-01
# 1                4.57       4.0             5.79        23.16     2023-01-01
# 2                4.60       3.0             7.77        23.31     2023-03-01
# 3                9.04       3.0            15.00        45.00     2023-06-01
# 4                3.37       4.0             4.08        16.32     2023-01-01
# ...               ...       ...              ...          ...            ...
# 78255            3.34       3.0             4.96        14.88     2023-07-01
# 78257            4.11       3.0             5.18        15.54     2023-04-01
# 78258            3.00      10.0             4.96        49.60     2023-03-01
# 78259            1.47       3.0             1.68         5.04     2023-06-01
# 78263            7.95       1.0            11.00        11.00     2023-06-01
#
#       MesCohorte MesCliente
# 0     2023-01-01         M1
# 1     2023-01-01         M1
# 2     2023-03-01         M1
# 3     2023-03-01         M4
# 4     2023-01-01         M1
# ...          ...        ...
# 78255 2023-07-01         M1
# 78257 2023-04-01         M1
# 78258 2023-03-01         M1
# 78259 2023-06-01         M1
# 78263 2023-06-01         M1
#
# [54405 rows x 12 columns]

# %% [markdown]
# ## Pivotar para obtener la tabla de cohortes
#
# - Se genera una tabla con MesCohorte como índice, que representa el mes en el que los clientes entraron en la cohorte, y MesTransaccion como columnas, que refleja los meses en los que realizaron transacciones.
# - Para cada celda, se cuenta el número de clientes únicos (ID_Cliente) que realizaron una transacción en ese mes específico dentro de la cohorte correspondiente.
# - Cualquier valor faltante (es decir, donde no hubo transacciones) se reemplaza por 0, y los valores se convierten a enteros.
# - El resultado es una tabla de cohortes en la que cada fila muestra cómo evoluciona el número de clientes activos a lo largo de los meses posteriores a su ingreso en la cohorte.

# %%
# Crear la tabla pivotada de cohortes para el análisis
cohorte_final_natural = pd.pivot_table(
    resultados_filtrados,
    index='MesCohorte',
    columns='MesTransaccion',
    values='ID_Cliente',
    aggfunc='nunique'  # Contar clientes únicos por cada cohorte y mes
).fillna(0).astype(int)  # Rellenar NaN con 0 y convertir a enteros

cohorte_final_natural
# Out:
# MesTransaccion  2023-01-01  2023-02-01  2023-03-01  2023-04-01  2023-05-01  \
# MesCohorte
# 2023-01-01            3114        1011         778         458         189
# 2023-02-01               0        2051         408         241         121
# 2023-03-01               0           0        2160         390         303
# 2023-04-01               0           0           0        2079         403
# 2023-05-01               0           0           0           0        2334
# 2023-06-01               0           0           0           0           0
# 2023-07-01               0           0           0           0           0
#
# MesTransaccion  2023-06-01  2023-07-01  2023-08-01  2023-09-01  2023-10-01  \
# MesCohorte
# 2023-01-01             134           0           0           0           0
# 2023-02-01              72          53           0           0           0
# 2023-03-01             261         206         213           0           0
# 2023-04-01             329         265         295         281           0
# 2023-05-01             434         380         311         373         361
# 2023-06-01            1461         210         203         212         206
# 2023-07-01               0        1168         147         156         162
#
# MesTransaccion  2023-11-01  2023-12-01
# MesCohorte
# 2023-01-01               0           0
# 2023-02-01               0           0
# 2023-03-01               0           0
# 2023-04-01               0           0
# 2023-05-01               0           0
# 2023-06-01             205           0
# 2023-07-01             154         170

# %% [markdown]
# ## Tabla de cohortes
#
# Esta tabla la obtendremos de forma similar a a la anterior, pero en las columnas en lugar de usar MesTransaccion, usaremos el propio MesCliente

# %%
# Crear la tabla pivotada de cohortes para el análisis
tabla_cohortes = pd.pivot_table(
    resultados_filtrados,
    index='MesCohorte',
    columns='MesCliente', # Permite ordenar las filas en los meses de cada cohorte
    values='ID_Cliente',
    aggfunc='nunique'  # Contar clientes únicos por cada cohorte y mes
).fillna(0).astype(int)  # Rellenar NaN con 0 y convertir a enteros

tabla_cohortes
# Out:
# MesCliente    M1    M2   M3   M4   M5   M6
# MesCohorte
# 2023-01-01  3114  1011  778  458  189  134
# 2023-02-01  2051   408  241  121   72   53
# 2023-03-01  2160   390  303  261  206  213
# 2023-04-01  2079   403  329  265  295  281
# 2023-05-01  2334   434  380  311  373  361
# 2023-06-01  1461   210  203  212  206  205
# 2023-07-01  1168   147  156  162  154  170

# %% [markdown]
# **Aplicar formato a la tabla**

# %%
# Tabla de cohortes formateada
tabla_cohortes_f = tabla_cohortes.style.background_gradient(cmap='Blues', axis=None)
tabla_cohortes_f
# Out:
# <style type="text/css">
# #T_16cd4_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_16cd4_row0_col1 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_16cd4_row0_col2 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_16cd4_row0_col3 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_16cd4_row0_col4, #T_16cd4_row2_col4, #T_16cd4_row5_col2, #T_16cd4_row5_col4, #T_16cd4_row5_col5 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_16cd4_row0_col5 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_16cd4_row1_col0 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_16cd4_row1_col1, #T_16cd4_row3_col1 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_16cd4_row1_col2 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_16cd4_row1_col3 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_16cd4_row1_col4 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_16cd4_row1_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_16cd4_row2_col0 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_16cd4_row2_col1 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_16cd4_row2_col2, #T_16cd4_row3_col4 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_16cd4_row2_col3, #T_16cd4_row3_col3 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_16cd4_row2_col5, #T_16cd4_row5_col1, #T_16cd4_row5_col3 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_16cd4_row3_col0 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_16cd4_row3_col2 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_16cd4_row3_col5 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_16cd4_row4_col0 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_16cd4_row4_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_16cd4_row4_col2 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_16cd4_row4_col3 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_16cd4_row4_col4 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_16cd4_row4_col5 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_16cd4_row5_col0 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_16cd4_row6_col0 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_16cd4_row6_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_16cd4_row6_col2, #T_16cd4_row6_col4 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_16cd4_row6_col3, #T_16cd4_row6_col5 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# </style>
# <table id="T_16cd4">
#   <thead>
#     <tr>
#       <th class="index_name level0" >MesCliente</th>
#       <th id="T_16cd4_level0_col0" class="col_heading level0 col0" >M1</th>
#       <th id="T_16cd4_level0_col1" class="col_heading level0 col1" >M2</th>
#       <th id="T_16cd4_level0_col2" class="col_heading level0 col2" >M3</th>
#       <th id="T_16cd4_level0_col3" class="col_heading level0 col3" >M4</th>
#       <th id="T_16cd4_level0_col4" class="col_heading level0 col4" >M5</th>
#       <th id="T_16cd4_level0_col5" class="col_heading level0 col5" >M6</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >MesCohorte</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16cd4_level0_row0" class="row_heading level0 row0" >2023-01-01 00:00:00</th>
#       <td id="T_16cd4_row0_col0" class="data row0 col0" >3114</td>
#       <td id="T_16cd4_row0_col1" class="data row0 col1" >1011</td>
#       <td id="T_16cd4_row0_col2" class="data row0 col2" >778</td>
#       <td id="T_16cd4_row0_col3" class="data row0 col3" >458</td>
#       <td id="T_16cd4_row0_col4" class="data row0 col4" >189</td>
#       <td id="T_16cd4_row0_col5" class="data row0 col5" >134</td>
#     </tr>
#     <tr>
#       <th id="T_16cd4_level0_row1" class="row_heading level0 row1" >2023-02-01 00:00:00</th>
#       <td id="T_16cd4_row1_col0" class="data row1 col0" >2051</td>
#       <td id="T_16cd4_row1_col1" class="data row1 col1" >408</td>
#       <td id="T_16cd4_row1_col2" class="data row1 col2" >241</td>
#       <td id="T_16cd4_row1_col3" class="data row1 col3" >121</td>
#       <td id="T_16cd4_row1_col4" class="data row1 col4" >72</td>
#       <td id="T_16cd4_row1_col5" class="data row1 col5" >53</td>
#     </tr>
#     <tr>
#       <th id="T_16cd4_level0_row2" class="row_heading level0 row2" >2023-03-01 00:00:00</th>
#       <td id="T_16cd4_row2_col0" class="data row2 col0" >2160</td>
#       <td id="T_16cd4_row2_col1" class="data row2 col1" >390</td>
#       <td id="T_16cd4_row2_col2" class="data row2 col2" >303</td>
#       <td id="T_16cd4_row2_col3" class="data row2 col3" >261</td>
#       <td id="T_16cd4_row2_col4" class="data row2 col4" >206</td>
#       <td id="T_16cd4_row2_col5" class="data row2 col5" >213</td>
#     </tr>
#     <tr>
#       <th id="T_16cd4_level0_row3" class="row_heading level0 row3" >2023-04-01 00:00:00</th>
#       <td id="T_16cd4_row3_col0" class="data row3 col0" >2079</td>
#       <td id="T_16cd4_row3_col1" class="data row3 col1" >403</td>
#       <td id="T_16cd4_row3_col2" class="data row3 col2" >329</td>
#       <td id="T_16cd4_row3_col3" class="data row3 col3" >265</td>
#       <td id="T_16cd4_row3_col4" class="data row3 col4" >295</td>
#       <td id="T_16cd4_row3_col5" class="data row3 col5" >281</td>
#     </tr>
#     <tr>
#       <th id="T_16cd4_level0_row4" class="row_heading level0 row4" >2023-05-01 00:00:00</th>
#       <td id="T_16cd4_row4_col0" class="data row4 col0" >2334</td>
#       <td id="T_16cd4_row4_col1" class="data row4 col1" >434</td>
#       <td id="T_16cd4_row4_col2" class="data row4 col2" >380</td>
#       <td id="T_16cd4_row4_col3" class="data row4 col3" >311</td>
#       <td id="T_16cd4_row4_col4" class="data row4 col4" >373</td>
#       <td id="T_16cd4_row4_col5" class="data row4 col5" >361</td>
#     </tr>
#     <tr>
#       <th id="T_16cd4_level0_row5" class="row_heading level0 row5" >2023-06-01 00:00:00</th>
#       <td id="T_16cd4_row5_col0" class="data row5 col0" >1461</td>
#       <td id="T_16cd4_row5_col1" class="data row5 col1" >210</td>
#       <td id="T_16cd4_row5_col2" class="data row5 col2" >203</td>
#       <td id="T_16cd4_row5_col3" class="data row5 col3" >212</td>
#       <td id="T_16cd4_row5_col4" class="data row5 col4" >206</td>
#       <td id="T_16cd4_row5_col5" class="data row5 col5" >205</td>
#     </tr>
#     <tr>
#       <th id="T_16cd4_level0_row6" class="row_heading level0 row6" >2023-07-01 00:00:00</th>
#       <td id="T_16cd4_row6_col0" class="data row6 col0" >1168</td>
#       <td id="T_16cd4_row6_col1" class="data row6 col1" >147</td>
#       <td id="T_16cd4_row6_col2" class="data row6 col2" >156</td>
#       <td id="T_16cd4_row6_col3" class="data row6 col3" >162</td>
#       <td id="T_16cd4_row6_col4" class="data row6 col4" >154</td>
#       <td id="T_16cd4_row6_col5" class="data row6 col5" >170</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Calcular tasa de retención
#
# Calculamos la tasa de retención para cada cohorte, dividiendo el número de clientes activos en cada mes de la cohorte entre el número de clientes que realizaron su primera compra en el mes de inicio de la cohorte (primer mes). Esto nos permite ver el porcentaje de clientes que continúan realizando transacciones en los meses posteriores a su primera compra.

# %%
# Calcular tabla de retención
tabla_retencion = tabla_cohortes.div(tabla_cohortes['M1'], axis=0) * 100

tabla_retencion = tabla_retencion.round(1)
tabla_retencion
# Out:
# MesCliente     M1    M2    M3    M4    M5    M6
# MesCohorte
# 2023-01-01  100.0  32.5  25.0  14.7   6.1   4.3
# 2023-02-01  100.0  19.9  11.8   5.9   3.5   2.6
# 2023-03-01  100.0  18.1  14.0  12.1   9.5   9.9
# 2023-04-01  100.0  19.4  15.8  12.7  14.2  13.5
# 2023-05-01  100.0  18.6  16.3  13.3  16.0  15.5
# 2023-06-01  100.0  14.4  13.9  14.5  14.1  14.0
# 2023-07-01  100.0  12.6  13.4  13.9  13.2  14.6

# %%
# Tabla de retención formateada
tabla_retencion_f = tabla_retencion.style.format("{:.1f}").background_gradient(cmap='Blues', axis=None)

# Mostrar la tabla con los valores formateados a 1 decimal
tabla_retencion_f
# Out:
# <style type="text/css">
# #T_87bcf_row0_col0, #T_87bcf_row1_col0, #T_87bcf_row2_col0, #T_87bcf_row3_col0, #T_87bcf_row4_col0, #T_87bcf_row5_col0, #T_87bcf_row6_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_87bcf_row0_col1 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_87bcf_row0_col2 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_87bcf_row0_col3, #T_87bcf_row5_col1, #T_87bcf_row5_col3, #T_87bcf_row6_col5 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_87bcf_row0_col4 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_87bcf_row0_col5 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_87bcf_row1_col1 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_87bcf_row1_col2, #T_87bcf_row2_col3 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_87bcf_row1_col3 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_87bcf_row1_col4 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_87bcf_row1_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_87bcf_row2_col1 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_87bcf_row2_col2, #T_87bcf_row5_col2, #T_87bcf_row5_col5, #T_87bcf_row6_col3 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_87bcf_row2_col4 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_87bcf_row2_col5 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_87bcf_row3_col1 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_87bcf_row3_col2 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_87bcf_row3_col3, #T_87bcf_row6_col1 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_87bcf_row3_col4, #T_87bcf_row5_col4 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_87bcf_row3_col5, #T_87bcf_row4_col3, #T_87bcf_row6_col2 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_87bcf_row4_col1 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_87bcf_row4_col2 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_87bcf_row4_col4 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_87bcf_row4_col5 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_87bcf_row6_col4 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# </style>
# <table id="T_87bcf">
#   <thead>
#     <tr>
#       <th class="index_name level0" >MesCliente</th>
#       <th id="T_87bcf_level0_col0" class="col_heading level0 col0" >M1</th>
#       <th id="T_87bcf_level0_col1" class="col_heading level0 col1" >M2</th>
#       <th id="T_87bcf_level0_col2" class="col_heading level0 col2" >M3</th>
#       <th id="T_87bcf_level0_col3" class="col_heading level0 col3" >M4</th>
#       <th id="T_87bcf_level0_col4" class="col_heading level0 col4" >M5</th>
#       <th id="T_87bcf_level0_col5" class="col_heading level0 col5" >M6</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >MesCohorte</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87bcf_level0_row0" class="row_heading level0 row0" >2023-01-01 00:00:00</th>
#       <td id="T_87bcf_row0_col0" class="data row0 col0" >100.0</td>
#       <td id="T_87bcf_row0_col1" class="data row0 col1" >32.5</td>
#       <td id="T_87bcf_row0_col2" class="data row0 col2" >25.0</td>
#       <td id="T_87bcf_row0_col3" class="data row0 col3" >14.7</td>
#       <td id="T_87bcf_row0_col4" class="data row0 col4" >6.1</td>
#       <td id="T_87bcf_row0_col5" class="data row0 col5" >4.3</td>
#     </tr>
#     <tr>
#       <th id="T_87bcf_level0_row1" class="row_heading level0 row1" >2023-02-01 00:00:00</th>
#       <td id="T_87bcf_row1_col0" class="data row1 col0" >100.0</td>
#       <td id="T_87bcf_row1_col1" class="data row1 col1" >19.9</td>
#       <td id="T_87bcf_row1_col2" class="data row1 col2" >11.8</td>
#       <td id="T_87bcf_row1_col3" class="data row1 col3" >5.9</td>
#       <td id="T_87bcf_row1_col4" class="data row1 col4" >3.5</td>
#       <td id="T_87bcf_row1_col5" class="data row1 col5" >2.6</td>
#     </tr>
#     <tr>
#       <th id="T_87bcf_level0_row2" class="row_heading level0 row2" >2023-03-01 00:00:00</th>
#       <td id="T_87bcf_row2_col0" class="data row2 col0" >100.0</td>
#       <td id="T_87bcf_row2_col1" class="data row2 col1" >18.1</td>
#       <td id="T_87bcf_row2_col2" class="data row2 col2" >14.0</td>
#       <td id="T_87bcf_row2_col3" class="data row2 col3" >12.1</td>
#       <td id="T_87bcf_row2_col4" class="data row2 col4" >9.5</td>
#       <td id="T_87bcf_row2_col5" class="data row2 col5" >9.9</td>
#     </tr>
#     <tr>
#       <th id="T_87bcf_level0_row3" class="row_heading level0 row3" >2023-04-01 00:00:00</th>
#       <td id="T_87bcf_row3_col0" class="data row3 col0" >100.0</td>
#       <td id="T_87bcf_row3_col1" class="data row3 col1" >19.4</td>
#       <td id="T_87bcf_row3_col2" class="data row3 col2" >15.8</td>
#       <td id="T_87bcf_row3_col3" class="data row3 col3" >12.7</td>
#       <td id="T_87bcf_row3_col4" class="data row3 col4" >14.2</td>
#       <td id="T_87bcf_row3_col5" class="data row3 col5" >13.5</td>
#     </tr>
#     <tr>
#       <th id="T_87bcf_level0_row4" class="row_heading level0 row4" >2023-05-01 00:00:00</th>
#       <td id="T_87bcf_row4_col0" class="data row4 col0" >100.0</td>
#       <td id="T_87bcf_row4_col1" class="data row4 col1" >18.6</td>
#       <td id="T_87bcf_row4_col2" class="data row4 col2" >16.3</td>
#       <td id="T_87bcf_row4_col3" class="data row4 col3" >13.3</td>
#       <td id="T_87bcf_row4_col4" class="data row4 col4" >16.0</td>
#       <td id="T_87bcf_row4_col5" class="data row4 col5" >15.5</td>
#     </tr>
#     <tr>
#       <th id="T_87bcf_level0_row5" class="row_heading level0 row5" >2023-06-01 00:00:00</th>
#       <td id="T_87bcf_row5_col0" class="data row5 col0" >100.0</td>
#       <td id="T_87bcf_row5_col1" class="data row5 col1" >14.4</td>
#       <td id="T_87bcf_row5_col2" class="data row5 col2" >13.9</td>
#       <td id="T_87bcf_row5_col3" class="data row5 col3" >14.5</td>
#       <td id="T_87bcf_row5_col4" class="data row5 col4" >14.1</td>
#       <td id="T_87bcf_row5_col5" class="data row5 col5" >14.0</td>
#     </tr>
#     <tr>
#       <th id="T_87bcf_level0_row6" class="row_heading level0 row6" >2023-07-01 00:00:00</th>
#       <td id="T_87bcf_row6_col0" class="data row6 col0" >100.0</td>
#       <td id="T_87bcf_row6_col1" class="data row6 col1" >12.6</td>
#       <td id="T_87bcf_row6_col2" class="data row6 col2" >13.4</td>
#       <td id="T_87bcf_row6_col3" class="data row6 col3" >13.9</td>
#       <td id="T_87bcf_row6_col4" class="data row6 col4" >13.2</td>
#       <td id="T_87bcf_row6_col5" class="data row6 col5" >14.6</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Observaciones**
#
# - La retención tiende a disminuir significativamente con el tiempo para cada cohorte, lo cual es típico, ya que muchos clientes no permanecen activos después de los primeros meses.
# - Algunas cohortes (como la de junio) parecen tener una retención más estable en los meses posteriores, manteniendo un porcentaje relativamente constante en los meses 3-6.

# %% [markdown]
# **Consultas con la tabla de retención**

# %%
# ¿Cuál es la tasa de retención media para cada cohorte?
tabla_retencion.mean()
# Out:
# MesCliente
# M1    100.000000
# M2     19.357143
# M3     15.742857
# M4     12.442857
# M5     10.942857
# M6     10.628571
# dtype: float64

# %% [markdown]
# **Observación**
#
# Esta aproximación no es del todo correcta, porque estamos promediando porcentajes de retención para cada cohorte sin considerar el tamaño original de la misma. (media de medias...). Esto puede llevar a una situación en la que una cohorte pequeña con una alta retención tenga el mismo peso que una cohorte grande con una baja retención, lo que distorsiona el resultado.
#
# Lo que realmente debemos hacer es calcular la retención promedio ponderada para cada cohorte, desde la tabla de absolutos...

# %%
# Sumar el total de clientes en M1 para todas las cohortes
total_inicial = tabla_cohortes['M1'].sum()

# Sumar el total de clientes retenidos en cada mes
total_retenidos = tabla_cohortes.sum()

# Calcular la tasa media
tasa_media = total_retenidos / total_inicial
tasa_media
# Out:
# MesCliente
# M1    1.000000
# M2    0.209021
# M3    0.166353
# M4    0.124591
# M5    0.104058
# M6    0.098629
# dtype: float64

# %%
tasa_media.plot(kind = 'bar');

# %%
# ¿cómo varía la cantidad de clientes activos mes a mes para cada cohorte?
tabla_retencion.T.plot(kind='line', figsize=(10, 6));

# %% [markdown]
# ### Cálculo de la tasa de retención global

# %%
# Tasa de retención global
# Calcular el total de clientes iniciales en todas las cohortes (M1 de todas las filas)
total_inicial_global = tabla_cohortes['M1'].sum()

# Calcular el total de clientes retenidos en el último mes (M6 en este caso)
total_retenidos_final = tabla_cohortes['M6'].sum()

# Calcular la tasa de retención global usando solo el último mes
tasa_retencion_global = total_retenidos_final / total_inicial_global
tasa_retencion_global
# Out:
# 0.09862880211596019

# %% [markdown]
# ## Código Cohortes unificado

# %%
# # Crear la columna 'MesTransaccion' a partir de 'Fecha' en formato Period (mes y año)
# productos['MesTransaccion'] = productos['Fecha'].dt.to_period('M')

# # Añadir el mes de cohorte
# productos['MesCohorte'] = productos.groupby('ID_Cliente')['MesTransaccion'].transform('min')

# # Eliminar registros de cohortes no completas
# resultados = productos[productos['MesCohorte'] <= '2023-07']

# # Transformar las variables Mes: a datetime
# resultados = resultados.copy()
# resultados['MesTransaccion'] = pd.to_datetime(resultados['MesTransaccion'].astype(str), format='%Y-%m')
# resultados['MesCohorte'] = pd.to_datetime(resultados['MesCohorte'].astype(str), format='%Y-%m')

# # Eliminar registros que no entran en el mes de cohorte de estudio
# resultados_filtrados = resultados[resultados['MesTransaccion'] <= resultados['MesCohorte'] + pd.DateOffset(months=5)]

# # Crear variable mes desde el punto de vista cliente
# resultados_filtrados = resultados_filtrados.copy()

# # Paso 1: Crear nuevas columnas temporales como Period[M] sin sobrescribir las originales
# mes_transaccion_period = resultados_filtrados['MesTransaccion'].dt.to_period('M')
# mes_cohorte_period = resultados_filtrados['MesCohorte'].dt.to_period('M')

# # Paso 2: Calcular la diferencia en meses entre las columnas temporales
# diferencia_meses = mes_transaccion_period - mes_cohorte_period

# # Paso 3: Crear la nueva columna 'MesCliente' con la diferencia calculada
# resultados_filtrados.loc[:, 'MesCliente'] = 'M' + diferencia_meses.apply(lambda x: str(x.n + 1))

# # Obtener tabla de cohortes
# # Crear la tabla pivotada de cohortes para el análisis
# tabla_cohortes = pd.pivot_table(
#     resultados_filtrados,
#     index='MesCohorte',
#     columns='MesCliente', # Permite ordenar las filas en los meses de cada cohorte
#     values='ID_Cliente',
#     aggfunc='nunique'  # Contar clientes únicos por cada cohorte y mes
# ).fillna(0).astype(int)  # Rellenar NaN con 0 y convertir a enteros

# # Calcular tabla de retención
# tabla_retencion = tabla_cohortes.div(tabla_cohortes['M1'], axis=0) * 100

# tabla_retencion = tabla_retencion.round(1)
